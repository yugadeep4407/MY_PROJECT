# %%
import pandas as pd
df=pd.read_csv("C:/Users/HP/Downloads/housing.csv")
df.head(30)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
# 5     -122.25     37.85                52.0        919.0           213.0
# 6     -122.25     37.84                52.0       2535.0           489.0
# 7     -122.25     37.84                52.0       3104.0           687.0
# 8     -122.26     37.84                42.0       2555.0           665.0
# 9     -122.25     37.84                52.0       3549.0           707.0
# 10    -122.26     37.85                52.0       2202.0           434.0
# 11    -122.26     37.85                52.0       3503.0           752.0
# 12    -122.26     37.85                52.0       2491.0           474.0
# 13    -122.26     37.84                52.0        696.0           191.0
# 14    -122.26     37.85                52.0       2643.0           626.0
# 15    -122.26     37.85                50.0       1120.0           283.0
# 16    -122.27     37.85                52.0       1966.0           347.0
# 17    -122.27     37.85                52.0       1228.0           293.0
# 18    -122.26     37.84                50.0       2239.0           455.0
# 19    -122.27     37.84                52.0       1503.0           298.0
# 20    -122.27     37.85                40.0        751.0           184.0
# 21    -122.27     37.85                42.0       1639.0           367.0
# 22    -122.27     37.84                52.0       2436.0           541.0
# 23    -122.27     37.84                52.0       1688.0           337.0
# 24    -122.27     37.84                52.0       2224.0           437.0
# 25    -122.28     37.85                41.0        535.0           123.0
# 26    -122.28     37.85                49.0       1130.0           244.0
# 27    -122.28     37.85                52.0       1898.0           421.0
# 28    -122.28     37.84                50.0       2082.0           492.0
# 29    -122.28     37.84                52.0        729.0           160.0
#
#     population  households  median_income  median_house_value ocean_proximity
# 0        322.0       126.0         8.3252            452600.0        NEAR BAY
# 1       2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2        496.0       177.0         7.2574            352100.0        NEAR BAY
# 3        558.0       219.0         5.6431            341300.0        NEAR BAY
# 4        565.0       259.0         3.8462            342200.0        NEAR BAY
# 5        413.0       193.0         4.0368            269700.0        NEAR BAY
# 6       1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7       1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8       1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9       1551.0       714.0         3.6912            261100.0        NEAR BAY
# 10       910.0       402.0         3.2031            281500.0        NEAR BAY
# 11      1504.0       734.0         3.2705            241800.0        NEAR BAY
# 12      1098.0       468.0         3.0750            213500.0        NEAR BAY
# 13       345.0       174.0         2.6736            191300.0        NEAR BAY
# 14      1212.0       620.0         1.9167            159200.0        NEAR BAY
# 15       697.0       264.0         2.1250            140000.0        NEAR BAY
# 16       793.0       331.0         2.7750            152500.0        NEAR BAY
# 17       648.0       303.0         2.1202            155500.0        NEAR BAY
# 18       990.0       419.0         1.9911            158700.0        NEAR BAY
# 19       690.0       275.0         2.6033            162900.0        NEAR BAY
# 20       409.0       166.0         1.3578            147500.0        NEAR BAY
# 21       929.0       366.0         1.7135            159800.0        NEAR BAY
# 22      1015.0       478.0         1.7250            113900.0        NEAR BAY
# 23       853.0       325.0         2.1806             99700.0        NEAR BAY
# 24      1006.0       422.0         2.6000            132600.0        NEAR BAY
# 25       317.0       119.0         2.4038            107500.0        NEAR BAY
# 26       607.0       239.0         2.4597             93800.0        NEAR BAY
# 27      1102.0       397.0         1.8080            105500.0        NEAR BAY
# 28      1131.0       473.0         1.6424            108900.0        NEAR BAY
# 29       395.0       155.0         1.6875            132000.0        NEAR BAY

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.shape
# Out:
# (20640, 10)

# %%
median = df['total_bedrooms'].median()
df['total_bedrooms'].fillna(median, inplace=True)

# %%
missing= df.isnull().sum()
print(missing)
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
#to find the duplicates
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value, ocean_proximity]
# Index: []

# %%
#to remove the duplicates
df_no_duplicates = df.drop_duplicates()
print(df_no_duplicates.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB
# None

# %%
numerical_columns = ['longitude', 'latitude', 'housing_median_age', 'total_rooms',
                     'total_bedrooms', 'population', 'households', 'median_income',
                     'median_house_value']

for col in numerical_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    print(Q1,Q3)
    

    lf= Q1 - 1.5 * IQR
    uf = Q3 + 1.5 * IQR

    df = df[(df[col] >= lf) & (df[col] <= uf)]
print(lf,uf)        

print(df.info())
# Out:
# -121.76 -118.03
# 33.94 37.75
# 20.0 38.0
# 1315.0 2572.0
# 278.0 531.0
# 742.0 1451.0
# 263.0 500.0
# 2.4375 4.375
# 110050.0 232150.0
# -73100.0 415300.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15743 entries, 2 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           15743 non-null  float64
#  1   latitude            15743 non-null  float64
#  2   housing_median_age  15743 non-null  float64
#  3   total_rooms         15743 non-null  float64
#  4   total_bedrooms      15743 non-null  float64
#  5   population          15743 non-null  float64
#  6   households          15743 non-null  float64
#  7   median_income       15743 non-null  float64
#  8   median_house_value  15743 non-null  float64
#  9   ocean_proximity     15743 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.3+ MB
# None

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15761 entries, 2 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           15761 non-null  float64
#  1   latitude            15761 non-null  float64
#  2   housing_median_age  15761 non-null  float64
#  3   total_rooms         15761 non-null  float64
#  4   total_bedrooms      15761 non-null  float64
#  5   population          15761 non-null  float64
#  6   households          15761 non-null  float64
#  7   median_income       15761 non-null  float64
#  8   median_house_value  15761 non-null  float64
#  9   ocean_proximity     15761 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.3+ MB
# None

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x=df['total_bedrooms'])
plt.show()
